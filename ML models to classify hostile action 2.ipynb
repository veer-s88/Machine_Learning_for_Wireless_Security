# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dcf_sim = pd.read_csv('simulation_results.csv')
dcf_sim_2 = pd.read_csv('simulation_results1.csv')
dcf_sim_3 = pd.read_csv('simulation_results2.csv')

dcf_rogue_1 = pd.read_csv('simulation_results_rogue_node1.csv')
dcf_rogue_2 = pd.read_csv('simulation_results_rogue_node2.csv')
dcf_rogue_3 = pd.read_csv('simulation_results_rogue_node3.csv')
dcf_rogue_4 = pd.read_csv('simulation_results_rogue_node4.csv')
dcf_rogue_5 = pd.read_csv('simulation_results_rogue_node5.csv')

# %%
dcf_sim.head()
# Out:
#    Unnamed: 0  number of nodes  collision probability  total throughput  \
# 0           0                1               0.000000      2.668034e+07
# 1           1                2               0.111140      2.712160e+07
# 2           2                3               0.179212      2.671265e+07
# 3           3                4               0.232375      2.610422e+07
# 4           4                5               0.266849      2.569304e+07
#
#    average delay  simulation time  dropped packet
# 0       0.000346        34.640919             0.0
# 1       0.000681        32.063724             0.0
# 2       0.001037        31.223079             1.0
# 3       0.001416        30.869226             1.0
# 4       0.001799        30.636045             8.0

# %%
dcf_sim_2.head()
# Out:
#    Unnamed: 0  number of nodes  collision probability  total throughput  \
# 0           0                1               0.000000      2.664954e+07
# 1           1                2               0.111230      2.710938e+07
# 2           2                3               0.180530      2.669454e+07
# 3           3                4               0.232910      2.606698e+07
# 4           4                5               0.266967      2.565780e+07
#
#    average delay  simulation time  dropped packet
# 0       0.000346        34.631073             0.0
# 1       0.000681        32.029956             0.0
# 2       0.001039        31.262931             0.0
# 3       0.001414        30.801996             0.0
# 4       0.001802        30.676032             5.0

# %%
dcf_rogue_1.head()
# Out:
#    Unnamed: 0  number of nodes  collision probability  total throughput  \
# 0           0                2               0.108676      2.740564e+07
# 1           1                3               0.187823      2.675257e+07
# 2           2                4               0.243173      2.609699e+07
# 3           3                5               0.279570      2.550302e+07
# 4           4                6               0.308441      2.503640e+07
#
#    average delay  simulation time  dropped packet
# 0       0.000680        31.868136             1.0
# 1       0.001063        31.098465             0.0
# 2       0.001479        30.772710             1.0
# 3       0.001909        30.507327             5.0
# 4       0.002366        30.396609             9.0

# %%
dcf_rogue_3.head()
# Out:
#    Unnamed: 0  number of nodes  collision probability  total throughput  \
# 0           0                4               0.278096      2.561148e+07
# 1           1                5               0.315131      2.507142e+07
# 2           2                6               0.344936      2.454024e+07
# 3           3                7               0.370228      2.410606e+07
# 4           4                8               0.394994      2.363428e+07
#
#    average delay  simulation time  dropped packet
# 0       0.001559        30.359862             4.0
# 1       0.002142        30.242916            13.0
# 2       0.002821        30.199968            26.0
# 3       0.003447        30.135195            35.0
# 4       0.004118        30.072519            52.0

# %%
dcf_rogue_5.head(6)
# Out:
#    Unnamed: 0  number of nodes  collision probability  total throughput  \
# 0           0                6               0.415104      2.326056e+07
# 1           1                7               0.435950      2.283836e+07
# 2           2                8               0.448195      2.254601e+07
# 3           3                9               0.466692      2.212375e+07
# 4           4               10               0.477035      2.199424e+07
# 5           5               11               0.487199      2.163815e+07
#
#    average delay  simulation time  dropped packet
# 0       0.003024        30.002148            60.0
# 1       0.003994        29.917737           106.0
# 2       0.005424        29.911185           124.0
# 3       0.006400        29.865618           172.0
# 4       0.007470        29.901024           204.0
# 5       0.008530        29.809917           249.0

# %%
dcf_sim.drop('Unnamed: 0', axis=1, inplace=True)
dcf_sim_2.drop('Unnamed: 0', axis=1, inplace=True)
dcf_sim_3.drop('Unnamed: 0', axis=1, inplace=True)

dcf_rogue_1.drop('Unnamed: 0', axis=1, inplace=True)
dcf_rogue_2.drop('Unnamed: 0', axis=1, inplace=True)
dcf_rogue_3.drop('Unnamed: 0', axis=1, inplace=True)
dcf_rogue_4.drop('Unnamed: 0', axis=1, inplace=True)
dcf_rogue_5.drop('Unnamed: 0', axis=1, inplace=True)

# %%
dcf_sim['Label'] = 0
dcf_sim_2['Label'] = 0
dcf_sim_3['Label'] = 0

dcf_rogue_1['Label'] = 1
dcf_rogue_2['Label'] = 1
dcf_rogue_3['Label'] = 1
dcf_rogue_4['Label'] = 1
dcf_rogue_5['Label'] = 1

# %%
joined_table = pd.concat([dcf_sim, dcf_sim_2, dcf_sim_3, dcf_rogue_1, dcf_rogue_2, dcf_rogue_3, dcf_rogue_4, dcf_rogue_5])
joined_table.reset_index(inplace=True)
joined_table.tail()
# Out:
#      index  number of nodes  collision probability  total throughput  \
# 460     50               56               0.681999      1.660711e+07
# 461     51               57               0.684166      1.652250e+07
# 462     52               58               0.686504      1.649452e+07
# 463     53               59               0.688645      1.639478e+07
# 464     54               60               0.690916      1.630497e+07
#
#      average delay  simulation time  dropped packet  Label
# 460       0.056353        29.780829          2941.0      1
# 461       0.058384        29.772801          3068.0      1
# 462       0.059670        29.800602          3108.0      1
# 463       0.059487        29.697597          3126.0      1
# 464       0.061609        29.792241          3183.0      1

# %%
joined_table.drop('index', inplace=True, axis=1)

# %%
joined_table.shape
# Out:
# (465, 7)

# %%
joined_table.head()
# Out:
#    number of nodes  collision probability  total throughput  average delay  \
# 0                1               0.000000      2.668034e+07       0.000346
# 1                2               0.111140      2.712160e+07       0.000681
# 2                3               0.179212      2.671265e+07       0.001037
# 3                4               0.232375      2.610422e+07       0.001416
# 4                5               0.266849      2.569304e+07       0.001799
#
#    simulation time  dropped packet  Label
# 0        34.640919             0.0      0
# 1        32.063724             0.0      0
# 2        31.223079             1.0      0
# 3        30.869226             1.0      0
# 4        30.636045             8.0      0

# %%
joined_table.isnull().sum()
# Out:
# number of nodes          0
# collision probability    0
# total throughput         0
# average delay            0
# simulation time          0
# dropped packet           0
# Label                    0
# dtype: int64

# %%
feature_cols = ['number of nodes', 'collision probability', 'total throughput', 'average delay']

# %%
X = joined_table[feature_cols]
y = joined_table['Label']

# %%
X
# Out:
#      number of nodes  collision probability  total throughput  average delay
# 0                  1               0.000000      2.668034e+07       0.000346
# 1                  2               0.111140      2.712160e+07       0.000681
# 2                  3               0.179212      2.671265e+07       0.001037
# 3                  4               0.232375      2.610422e+07       0.001416
# 4                  5               0.266849      2.569304e+07       0.001799
# ..               ...                    ...               ...            ...
# 460               56               0.681999      1.660711e+07       0.056353
# 461               57               0.684166      1.652250e+07       0.058384
# 462               58               0.686504      1.649452e+07       0.059670
# 463               59               0.688645      1.639478e+07       0.059487
# 464               60               0.690916      1.630497e+07       0.061609
#
# [465 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 460    1
# 461    1
# 462    1
# 463    1
# 464    1
# Name: Label, Length: 465, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train
# Out:
#      number of nodes  collision probability  total throughput  average delay
# 330               37               0.594772      1.906418e+07       0.025902
# 116               57               0.619771      1.838420e+07       0.028784
# 392               43               0.634091      1.802072e+07       0.036428
# 128                9               0.360399      2.423695e+07       0.003447
# 325               32               0.579889      1.952596e+07       0.021959
# ..               ...                    ...               ...            ...
# 26                27               0.514265      2.106257e+07       0.011924
# 402               53               0.657207      1.736756e+07       0.045518
# 452               48               0.662066      1.711979e+07       0.048616
# 376               27               0.574035      1.966105e+07       0.021524
# 267               31               0.556515      2.009130e+07       0.018147
#
# [325 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler

scl_x = StandardScaler()

# %%
X_train = scl_x.fit_transform(X_train)
X_test = scl_x.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.34841542,  0.56042487, -0.57760069,  0.43241604],
#        [ 1.52122757,  0.75939315, -0.84731827,  0.63989544],
#        [ 0.70025907,  0.8733671 , -0.99149455,  1.19029253],
#        ...,
#        [ 0.9934621 ,  1.09601842, -1.34885597,  2.06787646],
#        [-0.23799065,  0.39537812, -0.3408487 ,  0.11718614],
#        [-0.00342822,  0.2559436 , -0.17018604, -0.12595245]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[55,  0],
#        [12, 73]], dtype=int64)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("F1 score:", metrics.f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.9142857142857143
# Precision: 1.0
# Recall: 0.8588235294117647
# F1 score: 0.9240506329113923

# %%
class_names = [0, 1]
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="viridis")

plt.tight_layout()
plt.title('Confusion matrix: Logistic Regression Results')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

plt.show()

# %%
y_pred_proba = logreg.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.title('ROC Curve: Logistic Regression Model')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn import svm
clf = svm.SVC(gamma=10)
clf.fit(X_train, y_train)
y_pred_svm = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(y_test, y_pred_svm)
cnf_matrix
# Out:
# array([[55,  0],
#        [ 7, 78]], dtype=int64)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_svm))
print("Precision:",metrics.precision_score(y_test, y_pred_svm))
print("Recall:",metrics.recall_score(y_test, y_pred_svm))
print("F1 score:", metrics.f1_score(y_test, y_pred_svm))
# Out:
# Accuracy: 0.95
# Precision: 1.0
# Recall: 0.9176470588235294
# F1 score: 0.9570552147239264

# %%
class_names = [0, 1]
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="viridis")

plt.tight_layout()
plt.title('Confusion matrix: SVM Results')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(n_estimators=200)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(y_test, y_pred_rf)
cnf_matrix
# Out:
# array([[51,  4],
#        [17, 68]], dtype=int64)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_rf))
print("Precision:",metrics.precision_score(y_test, y_pred_rf))
print("Recall:",metrics.recall_score(y_test, y_pred_rf))
print("F1 score:", metrics.f1_score(y_test, y_pred_rf))
# Out:
# Accuracy: 0.85
# Precision: 0.9444444444444444
# Recall: 0.8
# F1 score: 0.8662420382165604

# %%
class_names = [0, 1]
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="viridis")

plt.tight_layout()
plt.title('Confusion matrix: Random Forest Results')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb_clf = GradientBoostingClassifier(n_estimators=300, learning_rate=0.2)
gb_clf.fit(X_train, y_train)
y_pred_gb = gb_clf.predict(X_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_gb))
print("Precision:",metrics.precision_score(y_test, y_pred_gb))
print("Recall:",metrics.recall_score(y_test, y_pred_gb))
print("F1 score:", metrics.f1_score(y_test, y_pred_gb))
# Out:
# Accuracy: 0.8785714285714286
# Precision: 0.9857142857142858
# Recall: 0.8117647058823529
# F1 score: 0.8903225806451613

# %%
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(y_test, y_pred_gb)
cnf_matrix
# Out:
# array([[54,  1],
#        [16, 69]], dtype=int64)

# %%
class_names = [0, 1]
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="viridis")

plt.tight_layout()
plt.title('Confusion matrix: Gradient Boosting Results')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

plt.show()

# %% [markdown]
# ## Random Forest Classifier with GridSearchCV

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
rf = RandomForestClassifier()

# %%
params = {'n_estimators': [50, 100, 200, 300]}

# %%
gs = GridSearchCV(rf, params, cv=5, n_jobs=-1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01)

# %%
scl_x = StandardScaler()
scale_X = scl_x.fit_transform(X_train)

# %%
gs_model = gs.fit(scale_X, y_train)

# %%
pd.DataFrame(gs_model.cv_results_).sort_values('mean_test_score',ascending=False)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_gamma  \
# 4       0.003793      0.000728         0.001202        0.000397          10
# 3       0.003388      0.000468         0.001216        0.000394           5
# 2       0.003014      0.000050         0.001276        0.000414           3
# 1       0.003012      0.000029         0.000999        0.000006           1
# 0       0.003233      0.000357         0.001798        0.000386         0.5
#
#            params  split0_test_score  split1_test_score  split2_test_score  \
# 4   {'gamma': 10}           0.934783           0.956522           0.902174
# 3    {'gamma': 5}           0.934783           0.934783           0.891304
# 2    {'gamma': 3}           0.923913           0.945652           0.891304
# 1    {'gamma': 1}           0.902174           0.902174           0.847826
# 0  {'gamma': 0.5}           0.869565           0.880435           0.782609
#
#    split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 4           0.913043           0.880435         0.917391        0.026267
# 3           0.913043           0.891304         0.913043        0.019444
# 2           0.891304           0.891304         0.908696        0.022382
# 1           0.891304           0.847826         0.878261        0.025165
# 0           0.847826           0.847826         0.845652        0.033958
#
#    rank_test_score
# 4                1
# 3                2
# 2                3
# 1                4
# 0                5

# %% [markdown]
# ## Gradient Boosting Classifier with GridSearchCV

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

# %%
gb = GradientBoostingClassifier()

# %%
params = {'n_estimators': [50, 100, 200, 300],
         'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3]}

# %%
gs = GridSearchCV(gb, params, cv=5)

# %%
gs_model = gs.fit(scale_X, y_train)

# %%
pd.DataFrame(gs_model.cv_results_).sort_values('mean_test_score',ascending=False)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 19       0.149771      0.008081         0.001130        0.000244
# 13       0.044838      0.000316         0.000201        0.000402
# 18       0.096924      0.002152         0.001005        0.000641
# 11       0.135899      0.003848         0.000800        0.000400
# 15       0.140061      0.006155         0.000991        0.000635
# 16       0.023480      0.000845         0.000400        0.000490
# 17       0.045187      0.000416         0.000791        0.000396
# 14       0.089830      0.001503         0.000983        0.000026
# 12       0.022394      0.000498         0.000405        0.000496
# 10       0.091781      0.003434         0.000584        0.000478
# 7        0.136432      0.001355         0.000418        0.000513
# 9        0.045695      0.000688         0.000284        0.000420
# 6        0.089690      0.001219         0.000384        0.000471
# 8        0.022648      0.001020         0.000402        0.000493
# 5        0.044581      0.000721         0.000000        0.000000
# 3        0.131739      0.002227         0.000602        0.000492
# 4        0.022001      0.000621         0.000200        0.000399
# 2        0.086728      0.002635         0.001015        0.000029
# 1        0.043215      0.001778         0.000600        0.000490
# 0        0.022206      0.001741         0.000398        0.000487
#
#    param_learning_rate param_n_estimators  \
# 19                 0.3                300
# 13                 0.2                100
# 18                 0.3                200
# 11                 0.1                300
# 15                 0.2                300
# 16                 0.3                 50
# 17                 0.3                100
# 14                 0.2                200
# 12                 0.2                 50
# 10                 0.1                200
# 7                 0.05                300
# 9                  0.1                100
# 6                 0.05                200
# 8                  0.1                 50
# 5                 0.05                100
# 3                 0.01                300
# 4                 0.05                 50
# 2                 0.01                200
# 1                 0.01                100
# 0                 0.01                 50
#
#                                           params  split0_test_score  \
# 19   {'learning_rate': 0.3, 'n_estimators': 300}           0.956522
# 13   {'learning_rate': 0.2, 'n_estimators': 100}           0.945652
# 18   {'learning_rate': 0.3, 'n_estimators': 200}           0.956522
# 11   {'learning_rate': 0.1, 'n_estimators': 300}           0.945652
# 15   {'learning_rate': 0.2, 'n_estimators': 300}           0.945652
# 16    {'learning_rate': 0.3, 'n_estimators': 50}           0.934783
# 17   {'learning_rate': 0.3, 'n_estimators': 100}           0.956522
# 14   {'learning_rate': 0.2, 'n_estimators': 200}           0.945652
# 12    {'learning_rate': 0.2, 'n_estimators': 50}           0.934783
# 10   {'learning_rate': 0.1, 'n_estimators': 200}           0.945652
# 7   {'learning_rate': 0.05, 'n_estimators': 300}           0.945652
# 9    {'learning_rate': 0.1, 'n_estimators': 100}           0.934783
# 6   {'learning_rate': 0.05, 'n_estimators': 200}           0.913043
# 8     {'learning_rate': 0.1, 'n_estimators': 50}           0.869565
# 5   {'learning_rate': 0.05, 'n_estimators': 100}           0.847826
# 3   {'learning_rate': 0.01, 'n_estimators': 300}           0.869565
# 4    {'learning_rate': 0.05, 'n_estimators': 50}           0.869565
# 2   {'learning_rate': 0.01, 'n_estimators': 200}           0.847826
# 1   {'learning_rate': 0.01, 'n_estimators': 100}           0.760870
# 0    {'learning_rate': 0.01, 'n_estimators': 50}           0.695652
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 19           0.923913           0.858696           0.913043
# 13           0.902174           0.836957           0.913043
# 18           0.869565           0.880435           0.913043
# 11           0.891304           0.858696           0.902174
# 15           0.869565           0.869565           0.913043
# 16           0.891304           0.847826           0.902174
# 17           0.869565           0.847826           0.913043
# 14           0.869565           0.847826           0.913043
# 12           0.891304           0.836957           0.902174
# 10           0.880435           0.836957           0.891304
# 7            0.869565           0.826087           0.902174
# 9            0.869565           0.847826           0.869565
# 6            0.880435           0.836957           0.869565
# 8            0.880435           0.815217           0.826087
# 5            0.858696           0.804348           0.836957
# 3            0.836957           0.804348           0.739130
# 4            0.836957           0.771739           0.750000
# 2            0.804348           0.728261           0.717391
# 1            0.673913           0.641304           0.706522
# 0            0.663043           0.652174           0.673913
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 19           0.847826         0.900000        0.040902                1
# 13           0.869565         0.893478        0.037275                2
# 18           0.836957         0.891304        0.040670                3
# 11           0.847826         0.889130        0.034646                4
# 15           0.826087         0.884783        0.041017                5
# 16           0.836957         0.882609        0.035985                6
# 17           0.826087         0.882609        0.046828                7
# 14           0.836957         0.882609        0.040902                7
# 12           0.847826         0.882609        0.035985                7
# 10           0.858696         0.882609        0.036635                7
# 7            0.847826         0.878261        0.042041               11
# 9            0.858696         0.876087        0.030435               12
# 6            0.836957         0.867391        0.028676               13
# 8            0.836957         0.845652        0.025165               14
# 5            0.815217         0.832609        0.020160               15
# 3            0.793478         0.808696        0.043803               16
# 4            0.771739         0.800000        0.045393               17
# 2            0.695652         0.758696        0.057680               18
# 1            0.728261         0.702174        0.041589               19
# 0            0.728261         0.682609        0.026978               20

# %% [markdown]
# ## SVM with GridSearchCV

# %%
from sklearn import svm
clf = svm.SVC()

# %%
params = {'gamma': [0.5, 1, 3, 5, 10, 20]}

# %%
gs = GridSearchCV(clf, params, cv=5)

# %%
gs_model = gs.fit(scale_X, y_train)

# %%
pd.DataFrame(gs_model.cv_results_).sort_values('mean_test_score',ascending=False)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_gamma  \
# 4       0.004022      0.000078         0.001425        0.000503          10
# 3       0.003584      0.000485         0.001430        0.000497           5
# 5       0.004900      0.000514         0.001636        0.000491          20
# 2       0.003073      0.000175         0.001382        0.000471           3
# 1       0.003006      0.000013         0.001390        0.000483           1
# 0       0.003465      0.000421         0.001811        0.000414         0.5
#
#            params  split0_test_score  split1_test_score  split2_test_score  \
# 4   {'gamma': 10}           0.934783           0.956522           0.902174
# 3    {'gamma': 5}           0.934783           0.934783           0.891304
# 5   {'gamma': 20}           0.934783           0.923913           0.902174
# 2    {'gamma': 3}           0.923913           0.945652           0.891304
# 1    {'gamma': 1}           0.902174           0.902174           0.847826
# 0  {'gamma': 0.5}           0.869565           0.880435           0.782609
#
#    split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 4           0.913043           0.880435         0.917391        0.026267
# 3           0.913043           0.891304         0.913043        0.019444
# 5           0.913043           0.880435         0.910870        0.018701
# 2           0.891304           0.891304         0.908696        0.022382
# 1           0.891304           0.847826         0.878261        0.025165
# 0           0.847826           0.847826         0.845652        0.033958
#
#    rank_test_score
# 4                1
# 3                2
# 5                3
# 2                4
# 1                5
# 0                6
